# %% [markdown]
# # Exercise: visualisation and analysis of the dataset

# %%
# import libraries
import numpy
import matplotlib.pyplot as plt

# load dataset
data = numpy.loadtxt(fname= "data/inflammation-01.csv",
                    delimiter= ',')
#print(data)

# create fig variable
fig = plt.figure(figsize= (10, 3))

# add subplots
axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

# add labels
axes1.set_ylabel("max")
axes2.set_ylabel("min")
axes3.set_ylabel("mean")

# calculate the statistics: mean, max, min of patients over time (axis = 0)
axes1.plot(numpy.amax(data, axis = 0))
axes2.plot(numpy.amin(data, axis =0))
axes3.plot(numpy.mean(data, axis = 0))
# optional: save in a png
fig.plt.savefig("inflammation.png")

# %% [markdown]
# ## Exercise
#
# ### Loop analysis over filenames
#
# Steps:
# 1. Identify `for-loop` variable
# 2. Create list of filenames in alphabetical order
# 3. Add analysis/computations from last day to `for-loop`

# %%
# 1. Install libraries
import glob
import numpy # calculate stats
import matplotlib.pyplot as plt # visualise

# 2. Find the filenames with a variable filenames
filenames = sorted(glob.glob("data/inflammation*.csv")) # use sorted function for alph order

# 3. create the loop function to load the files in the filenames variable
# import the data for each file
for filename in filenames:
    data = numpy.loadtxt(fname = filename, delimiter = ',')
    fig = plt.figure(figsize = (10, 3))
    # adding the subplots
    axes1 = fig.add_subplot(1, 3, 1) #rows, cols, position
    axes2 = fig.add_subplot(1,3, 2)
    axes3 = fig.add_subplot(1, 3, 3)
    
    # adding the labels
    axes1.set_ylabel("max")
    axes2.set_ylabel("min")
    axes3.set_ylabel("mean")
    fig.supxlabel(filename) # add a label in x-axis for each filename
    
    # calculate the stats
    axes1.plot(numpy.amax(data, axis=0))
    axes2.plot(numpy.amin(data, axis=0))
    axes3.plot(numpy.mean(data, axis=0))
